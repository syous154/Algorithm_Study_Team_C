# %% [markdown]
# # 📝 문제 정보 (BOJ 11053)
# * 문제 이름: 가장 긴 증가하는 부분 수열
# * 문제 링크: https://www.acmicpc.net/problem/11053
# * 난이도: Silver 2
# * 알고리즘 유형: 다이나믹 프로그래밍
#
# ## 문제 설명
# 수열 A가 주어졌을 때, 가장 긴 증가하는 부분 수열을 구하는 프로그램을 작성하시오.
# 예를 들어, 수열 A = {10, 20, 10, 30, 20, 50} 인 경우에 가장 긴 증가하는 부분 수열은 A = {10, 20, 10, 30, 20, 50} 이고, 길이는 4이다.
#
# ### 입력
# 첫째 줄에 수열 A의 크기 N (1 ≤ N ≤ 1,000)이 주어진다.
# 둘째 줄에는 수열 A를 이루고 있는 Ai가 주어진다. (1 ≤ Ai ≤ 1,000)
#
# ### 출력
# 첫째 줄에 수열 A의 가장 긴 증가하는 부분 수열의 길이를 출력한다.
#
# ### 예제 입력 1
# ```
# 입력:
# 6
# 10 20 10 30 20 50
# 출력:
# 4
# ```

# %% [markdown]
# # 💡 접근 방법
# 1. DP를 통해서 해당 위치에 있는 값들을 기반으로 추가가 가능한지 여부 파악 후 진행.
# 2.
# 3.
#
# # ⏱️ 시간복잡도
# O()
#
# # 🗃️ 공간복잡도
# O()

# %%
# 코드 작성
def solution():
    # 여기에 코드를 작성하세요
    n = int(input())
    num_list = list(map(int, input().split()))
    dp = [1] * n
    for i in range(1, n):
        for j in range(0, i):
            if num_list[j] < num_list[i]: # 증가하는 수열
                dp[i] = max(dp[i], dp[j]+1)
    print(max(dp))

    pass

# 입력 처리
if __name__ == "__main__":
    solution()
# Out:
# 4

# %% [markdown]
# # 🧐 배운 점 & 어려웠던 점
# - 처음에 식 세우는 과정이 가장 어려웟음.
# -
# -
#
# # ✅ 자가 체크리스트
# - [X] 코드가 모든 테스트 케이스를 통과하나요?
# - [ ] 더 최적화할 수 있는 방법이 있나요?
# - [x] 코드에 주석을 충분히 달았나요?
