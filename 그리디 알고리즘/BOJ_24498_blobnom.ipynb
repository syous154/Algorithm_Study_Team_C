# %% [markdown]
# # 📝 문제 정보 (BOJ 24498)
# * 문제 이름: blobnom
# * 문제 링크: https://www.acmicpc.net/problem/24498
# * 난이도: Silver 3
# * 알고리즘 유형: 그리디 알고리즘
#
# ## 문제 설명
# 블롭들은 심심해서 서로를 이용해 $N$개의 탑을 만들었다. 각 탑의 높이는 그 탑에 있는 블롭의 수와 같다.
#
# 여러분은 다음 행동을 $0$회 이상 할 수 있다.
#
# 처음과 마지막이 아닌 탑 중 하나를 선택한다. 단, 선택한 탑과 인접한 두 탑의 높이가 모두 $1$ 이상이어야 한다.
# 선택한 탑과 인접한 두 탑에 있는 블롭을 한 마리씩 각각 땅에 내려놓는다. 즉, 인접한 두 탑의 높이가 모두 $1$만큼 감소한다.
# 땅에 내려놓은 두 마리의 블롭 중 하나의 블롭만 1.에서 선택한 탑에 쌓는다. 즉, 선택한 탑의 높이가 $1$만큼 증가한다.
#
# 이 과정에서 이전에 인접하지 않았던 두 탑이 새롭게 인접하게 되지는 않는다. 채완이를 위해 만들 수 있는 가장 높은 탑의 높이를 구해 주자.
#
# ### 입력
# 첫째 줄에 탑의 개수 $N$이 주어진다.
# 둘째 줄에 각 탑의 높이 $A_1, A_2, \cdots, A_N$이 공백으로 구분되어 주어진다.
#
# ### 출력
# 문제의 정답을 출력한다.
#
# ### 예제 입력 1
# ```
# 입력:
# 4
# 1 3 2 2
# 출력:
# 4
# ```
#
# ### 예제 입출력 2
# ```
# 입력:
# 5
# 2 4 3 5 5
# 출력:
# 8
# ```

# %% [markdown]
# # 💡 접근 방법
# 1. for문을 통해 리스트 순회
# 2. 처음과 마지막은 제외
# 3.
#
# # ⏱️ 시간복잡도
# O(n)
#
# # 🗃️ 공간복잡도
# O(n)

# %%
# 코드 작성
def solution():
    # 여기에 코드를 작성하세요
    _ = int(input())
    num_list = list(map(int, input().split()))
    max_height = max(num_list)
    for i in range(1, len(num_list)-1): # 처음과 마지막 제외
        # 인접한 2개의 불록에서 가져오는 과정중으로 리스트를 순회하면서 가장 높게 쌓을 수 있을지를 확인.
        current_height = (num_list[i]+min(num_list[i-1], num_list[i+1]))
        max_height = max(max_height, current_height)
    print(max_height)
# 입력 처리
if __name__ == "__main__":
    solution()
# Out:
# 8

# %% [markdown]
# # 🧐 배운 점 & 어려웠던 점
# - 문제의 처음 이해가 어려웠다.
# - 처음과 끝이 앞도적으로 높은 경우에 대한 고려를 하지 않음.
# -
#
# # ✅ 자가 체크리스트
# - [X] 코드가 모든 테스트 케이스를 통과하나요?
# - [ ] 더 최적화할 수 있는 방법이 있나요?
# - [X] 코드에 주석을 충분히 달았나요?
